# %% [markdown]
# <a href="https://colab.research.google.com/github/RohitMangale/ML/blob/main/pythonLibraries/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn Introduction
#
# Seaborn is a data visualization library in Python. It is used to produce statistical graphics in Python. It is built on top of Matplotlib. It also supports NumPy and Pandas data structures. It also supports statistical units from SciPy.

# %% [markdown]
# # Comparison Seaborn and Matplotlib
#
# **Seaborn** is a Python library that builds upon **Matplotlib**. It provides a higher-level interface, making it easier to create attractive and informative plots with less code. Seaborn uses Matplotlib to draw plots. Many actions can be accomplished with only Seaborn functions. Further customization options might require using Matplotlib directly. Seaborn is not an alternative to Matplotlib. We can think of it as a complement to Matplotlib. As it is built on top of Matplotlib, we can call Matplotlib functions directly for creating simple plots.
#
# **Key benefits of Seaborn:**
#
# * **Simplified API:** Seaborn offers a more intuitive API, reducing the amount of boilerplate code needed for basic visualizations.
# * **Theming and Styles:** It comes with built-in themes and styles that enhance the visual appeal of your plots.
# * **Statistical Visualization:** Seaborn is particularly well-suited for statistical visualizations, such as regression plots, heatmaps, and categorical plots.
# * **Data Frame Integration:** It works seamlessly with Pandas DataFrames, making it easier to visualize your data directly from data analysis workflows.
#
# **Why use Seaborn instead of Matplotlib alone?**
#
# * **Faster Development:** Seaborn's higher-level API allows you to create visually appealing plots more quickly.
# * **Improved Aesthetics:** Seaborn's built-in themes and styles can help you create plots that are more visually appealing and consistent.
# * **Statistical Focus:** If you're working with statistical data, Seaborn provides specialized functions and visualizations that are tailored to your needs.
#
# **In essence,** Seaborn is a valuable tool for data visualization that can save you time and effort, especially if you're working with statistical data or want to create visually appealing plots without diving deep into Matplotlib's intricacies.

# %% [markdown]
# # Plots in Seaborn
# Seaborn has various types of plots which can satisfy various types of data visualization requirements. The plots can be categorized into seven categories – relational plots, categorical plots, distribution plots, regression plots, matrix plots and multi-plot grids.

# %% [markdown]
# # Importing necessary python libraries

# %%
# %matplotlib inline
# this line is used to display plots in the o/p cells itself instead of a separate window
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
import pandas as pd

sns.set()  # seaborn's method to set its chart style
# it is definitely better than matplotlib's style

# %% [markdown]
# # Loading Datasets in Seaborn
# The `sns.load_dataset()` function loads the dataset from the Seaborn library itself. Seaborn comes bundled with several built-in datasets that are commonly used for data visualization examples and tutorials. These datasets are stored within the Seaborn package.
#
# When you call `sns.load_dataset()`, Seaborn searches for the dataset within its internal collection and returns it as a Pandas DataFrame. This DataFrame can then be used for various visualization tasks using Seaborn's functions.
#
# Here are some of the most commonly used built-in datasets:
#
# You can use the `sns.get_dataset_names()` function to get a complete list of all the built-in datasets available in Seaborn.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
display(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # General principles for using color in plots
#
# Colors play a significant role to help us identify and distinguish different data in the plots.
#
# Attributes of colors are hue,saturation, luminious(or lightness)
#
# Hue is the component that distinguishes “different colors” in a non-technical sense. It’s property of color that leads to first-order names like “red” and “blue”:
#
# ![image.png](data:image/png;base64,...)
#
# Saturation (or chroma) is the colorfulness. Two colors with different hues will look more distinct when they have more saturation:
#
# ![image.png](data:image/png;base64,...)
#
# And lightness corresponds to how much light is emitted (or reflected, for printed colors), ranging from black to white:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## histplot (histogram plot )
# A hisplot, or histogram plot, is a statistical visualization that represents the distribution of a numerical dataset. It divides the data into bins and counts the number of observations falling into each bin. The resulting graph shows the frequency of data points within each bin, often displayed as bars.

# %%
diamonds = sns.load_dataset('diamonds')
display(diamonds.head())
# sns.set_theme(style="ticks") # if the default theme is set you don't see the ticks

f,ax = plt.subplots(figsize=(7,5)) # figsize= (width,height) in inches
sns.histplot(
  data=diamonds,
  x = 'price',
  hue='cut',
  multiple="stack",
  palette="light:m_r",
  edgecolor=".3",
  linewidth=.5,
  log_scale=True,
  )
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500, 1000, 2000, 5000, 10000])
sns.despine(f) #  Removes the top and right spines (the borders around the plot) from the plot for a cleaner look.
# if you are wondering why only top and left then you are not the only one, the bottom and left are axis (they are imp right?)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# **Why is histogram plot used:**
#
# Histogram plot is used to plot data which includes counts or frequncy of somthing
#
# **Inference:**
#
# The graph shows the distribution of diamond prices based on their cut quality. The most common diamond cut is "Ideal," followed by "Premium" and "Very Good." As the cut quality decreases to "Fair," the number of diamonds also decreases significantly. The price range for diamonds with each cut overlaps, indicating that other factors besides cut influence the price.
#
# You can see that that diamonds are mostly priced at 900 and 5000. the graph is like **london bridge**.

# %% [markdown]
# ## kdeplot
#
# Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. It is used for non-parametric analysis.

# %%
tips = sns.load_dataset('tips')
sns.kdeplot(tips['total_bill'])

plt.show()

# %% [markdown]
# **Infernece:**
#
# The graph shows the probability density function of the total bill amounts. The distribution is skewed to the right, indicating that there are a few very large bills that pull the mean to the right. The peak of the distribution is around 15, suggesting that this is the most common total bill amount. The distribution has a long tail to the right, indicating that there are some very large bills that are relatively rare.

# %%
iris = sns.load_dataset('iris')
display(iris.head())

f,ax = plt.subplots(figsize=(8,8))
ax.set_aspect('equal')

sns.kdeplot(
    data=iris,
    x ='sepal_length',
    y='sepal_width',
    hue='species',
    thresh = .1, # This parameter controls the threshold for plotting the density. Areas with density below this value will not be displayed.

)

# the plot in enclosed cuz it is bivariate ,i.e. there are 2 variables x and y used
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# **Inference:**
#
# The graph shows the joint distribution of sepal length and sepal width for the three species of iris. The density contours overlap, indicating that there is some overlap between the distributions of the three species. However, the distributions are also distinct, suggesting that sepal length and sepal width can be used to distinguish between the three species. The setosa species has a lower sepal length and sepal width than the other two species. The virginica species has a higher sepal length and sepal width than the other two species. The versicolor species has a sepal length and sepal width that is intermediate between the setosa and virginica species.

# %%
penguins = sns.load_dataset('penguins')
display(penguins.head())

f,ax = plt.subplots(figsize=(8,8))
ax.set_aspect('equal')

sns.kdeplot(
    data=penguins,
    x ='bill_length_mm',
    y='flipper_length_mm',
    hue='species',


)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# **Inference:**
#
# The graph shows the joint distribution of bill length and flipper length for the three species of penguin. The density contours overlap, indicating that there is some overlap between the distributions of the three species. However, the distributions are also distinct, suggesting that bill length and flipper length can be used to distinguish between the three species. The Adelie species has a lower bill length and flipper length than the other two species. The Gentoo species has a higher bill length and flipper length than the other two species. The Chinstrap species has a bill length and flipper length that is intermediate between the Adelie and Gentoo species.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import gaussian_kde
import seaborn as sns


# Load the Penguins dataset
penguins = sns.load_dataset("penguins")
penguins = penguins.dropna(subset=['flipper_length_mm', 'bill_length_mm', 'bill_depth_mm'])
data = penguins[['flipper_length_mm', 'bill_length_mm', 'bill_depth_mm']].values.T  # Transpose for KDE

# Create a grid for evaluation
x = np.linspace(data[0].min(), data[0].max(), 100)
y = np.linspace(data[1].min(), data[1].max(), 100)
x, y = np.meshgrid(x, y)

# Evaluate the KDE
xy = np.vstack([data[0], data[1]])
z = gaussian_kde(xy)(np.vstack([x.ravel(), y.ravel()]))
z = z.reshape(x.shape)

# Plot the 3D surface
fig = plt.figure(figsize=(15, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
ax.set_xlabel('Flipper Length (mm)')
ax.set_ylabel('Bill Length (mm)')
ax.set_zlabel('Density')
ax.set_title('3D KDE of Penguins Flipper and Bill Dimensions')
plt.show()

# %% [markdown]
# **Inference:**
#
# The data shows two distinct clusters in the joint distribution of flipper length and bill length. The peaks in the density plot indicate regions where the data points are more concentrated.
# There is a moderate positive correlation between flipper length and bill length. The clusters are elongated along a diagonal, suggesting that penguins with longer flippers tend to also have longer bills.
# The distribution of flipper length is more spread out than the distribution of bill length. The base of the density plot is wider along the flipper length axis, indicating greater variability in flipper lengths compared to bill lengths.

# %% [markdown]
# # DistPlot
# The distplot() function provides a quick look at univariate distribution. This function will plot a histogram that fits the kernel density estimate of the data.

# %%
flights = sns.load_dataset('flights')
sns.distplot(flights['passengers'])

plt.show()
# Out:
# <ipython-input-65-facf0f13fb47>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(flights['passengers'])

# %% [markdown]
# **Inference:**
#
# The distribution of passenger counts is skewed to the right. There is a longer tail on the right side of the distribution, indicating that there are a few flights with significantly higher passenger counts than the majority.
# The most common passenger count range is between 200 and 300. This is evident from the tallest bar in the histogram and the peak in the density plot.
# The distribution is unimodal. There is a single peak in the distribution, suggesting that there is a central tendency in the passenger counts.

# %% [markdown]
# # ecdfplot

# %%
penguins = sns.load_dataset('penguins')
display(penguins.head())

sns.ecdfplot(data=penguins, x="flipper_length_mm")
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# <Axes: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# **Inference:**
# The data shows a right-skewed distribution. The CDF curve rises slowly at the beginning, indicating a concentration of data points in the lower range, and then rises more steeply towards the end, indicating a tail of larger values.
# The median flipper length is approximately 200 mm. This is the value at which the CDF curve crosses the 0.5 mark on the y-axis.
# The majority of penguins have flipper lengths between 180 and 220 mm. The steepest part of the CDF curve is between these values, indicating that most of the data points fall within this range.

# %% [markdown]
# # Rugplot
# Plot marginal distributions by drawing ticks along the x and y axes.
#
# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.

# %%
tips = sns.load_dataset("tips")
display(tips.head())
# sns.palplot(sns.color_palette('plasma'))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
sns.rugplot(data=tips, x="total_bill", y="tip", hue="day")
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **Inference:**
#
# There is a general positive relationship between total bill and tip amount. As the total bill increases, the tip amount tends to increase as well.
# The relationship is not perfectly linear. There is some scatter around the trend line, indicating that other factors besides total bill may influence tip amount.
# The tips vary more widely for larger total bills. The points are more spread out on the right side of the plot, suggesting that the tip percentage can vary more significantly for larger bills.

# %% [markdown]
# # Pie Charts
#
# Seaborn doesn't create pie charts.
# You can use matplotlib for it

# %%
mpg = sns.load_dataset("mpg")

origin_counts = mpg['origin'].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(origin_counts, labels=origin_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Car Origins in the MPG Dataset")
plt.show()

# %% [markdown]
# **Inference:**
#
# The majority of cars in the dataset are from the USA. This country accounts for 62.6% of the total cars.
# Japan and Europe have a smaller share of cars in the dataset. Japan accounts for 19.8% and Europe for 17.6%.
# The distribution of car origins is skewed towards the USA. The pie chart shows a clear dominance of cars from the USA, with the other two regions having relatively smaller portions.

# %% [markdown]
# # Bar Charts

# %%
f,ax = plt.subplots(figsize= (4,4))
tips = sns.load_dataset('tips').sort_values("total_bill", ascending=False)

sns.barplot(data = tips , x = 'total_bill',y = 'day',label = 'total_bill')
sns.barplot(data = tips ,x = 'tip',y = 'day',label = 'tip')

ax.legend(ncol=2, loc="lower right")
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Tips per Total Bill")
# Out:
# [(0.0, 24.0), Text(0, 0.5, ''), Text(0.5, 0, 'Tips per Total Bill')]

# %% [markdown]
# **Inference:**
#
# The average total bill and tip amounts vary across the days of the week. The lengths of the boxes and whiskers indicate differences in the central tendencies and spreads of the distributions.
# Total bills are generally higher on weekends (Sat and Sun) compared to weekdays (Thur and Fri). The median lines for total_bill are longer on Sat and Sun.
# Tips tend to be higher on Fridays and Saturdays. The median lines for tip are higher on these days, suggesting a tendency for larger tips on weekends.

# %% [markdown]
# # Scatter Plot

# %%
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",

                sizes=(1, 8), linewidth=0,
                data=diamonds,
                )
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# **Inference:**
#
# There is a strong positive correlation between carat weight and price. As carat weight increases, the price tends to increase as well, forming a clear upward trend.
# Clarity and depth also influence price. The different colors and sizes of the points suggest that diamonds with higher clarity grades and greater depths tend to have higher prices, even when controlling for carat weight.
# There are some outliers in the data. A few diamonds with relatively large carats and high clarity grades have lower prices than expected, suggesting that other factors besides carat, clarity, and depth may also influence price.

# %% [markdown]
# # Box Plot

# %%
taxis = sns.load_dataset('mpg')
display(taxis.head())
sns.set_theme(style="ticks", palette="pastel")
f,ax = plt.subplots(figsize = (20,7))

sns.boxplot(x="model_year", y="horsepower",
            hue="origin", palette=["y", "g","m"],
            data=taxis)
sns.despine(offset=10, trim=True)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# **Inference:**
#
# 1. **Horsepower has increased over time.** The median lines for each model year generally move upward, indicating a trend towards higher horsepower.
# 2. **The variation in horsepower within each model year has decreased over time.** The whiskers and boxes become narrower as the model year increases, suggesting that cars produced in later years have more consistent horsepower.
# 3. **The distribution of horsepower differs across car origins.** The boxes and whiskers for different origins overlap, but there are some noticeable differences, suggesting that the horsepower of cars varies depending on their origin.

# %% [markdown]
# # Violin Plots

# %%
import seaborn as sns
sns.set_theme(style="dark")

taxis = sns.load_dataset("taxis")
f,ax = plt.subplots(figsize = (10,10))

sns.violinplot(data=taxis, x="pickup_borough", y="fare", hue="color",
               split=True, inner="quart", fill=False,
               palette={"green": "g", "yellow": "y"})
# Out:
# <Axes: xlabel='pickup_borough', ylabel='fare'>

# %% [markdown]
# **Inference:**
#
# 1. **The distribution of fares varies across the different boroughs.** The shapes of the violin plots differ, indicating that the central tendencies and spreads of the fare distributions are not the same.
# 2. **Manhattan tends to have higher fares than the other boroughs.** The violin plot for Manhattan is generally higher, suggesting that the majority of fares in Manhattan are higher than in the other boroughs.
# 3. **There is more variability in fares in Brooklyn compared to the other boroughs.** The violin plot for Brooklyn is wider, indicating a larger spread of fares in that borough.

# %% [markdown]
# # PairPlot

# %%
import seaborn as sns
sns.set_theme(style="ticks")

mpg = sns.load_dataset("mpg")

sns.pairplot(mpg[['acceleration','weight','displacement','origin','horsepower']], hue="origin")

# %% [markdown]
# **Inference:**
#
# 1. **There are relationships between multiple variables.** The scatter plots in the off-diagonal panels show various relationships between acceleration, weight, displacement, and horsepower.
# 2. **Weight and displacement are positively correlated.** As weight increases, displacement tends to increase as well, suggesting a relationship between these two variables.
# 3. **Horsepower and acceleration have a negative correlation.** As horsepower increases, acceleration tends to decrease, indicating a trade-off between these two attributes.

# %% [markdown]
# # HeatMaps

# %%
healthexp_long = sns.load_dataset('healthexp')
sns.set_theme()
display(healthexp_long.head())

healthexp = healthexp_long[healthexp_long['Year'] > 1993].pivot(index='Country',columns='Year',values='Life_Expectancy')
f,ax = plt.subplots(figsize=(24,4))

sns.heatmap(healthexp,annot=True,fmt='.1f',linewidths=.5,ax=ax,) #fmt = '.1f' for float
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9
# <Axes: xlabel='Year', ylabel='Country'>

# %% [markdown]
# **Inference:**
# 1. **Life expectancy has generally increased over time for all countries.** The colors in the heatmap shift from darker (lower values) to lighter (higher values) as the years progress, indicating a general upward trend.
# 2. **There are variations in the rate of increase across countries.** Some countries experienced more rapid increases in life expectancy than others, resulting in different patterns of color change.
# 3. **Japan consistently had the highest life expectancy throughout the period.** The darkest colors in the Japan row indicate consistently higher values compared to the other countries.

# %% [markdown]
# # Line Chart

# %%
flights = sns.load_dataset("flights")
display(flights.head())

sns.lineplot(data = flights,x = 'year',y = 'passengers',hue = 'month',linestyle='dotted')
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# **Inference:**
# 1. **The number of passengers has increased over time.** All lines show an upward trend, indicating that the number of passengers has generally grown from 1949 to 1960.
# 2. **There are seasonal variations in passenger numbers.** The lines fluctuate throughout the year, suggesting that certain months have higher or lower passenger counts than others.
# 3. **The seasonal patterns appear consistent over time.** The peaks and troughs of the lines occur at similar points in the year, indicating a repeating seasonal pattern.

# %% [markdown]
# # Strip Plot
# A stripplot() is used to draw a scatterplot where one variable is categorical. It represents the data in sorted order along any one of the axis.

# %%
import seaborn as sns

iris = sns.load_dataset("iris")

sns.stripplot(data=iris,x="species", y="sepal_length", )

plt.show()

# %% [markdown]
# **Inference:**
# 1. **Sepal length varies across the three species.** The data points for each species cluster in different regions along the x-axis, indicating that sepal length is a distinguishing feature among the species.
# 2. **Setosa has the shortest sepal lengths, while virginica has the longest.** The clusters for setosa are on the left side of the plot, and the clusters for virginica are on the right side, suggesting a clear difference in sepal length between these two species.
# 3. **Versicolor has intermediate sepal lengths.** The data points for versicolor are located between setosa and virginica, indicating that their sepal lengths fall between the other two species.

# %% [markdown]
# # Point Plot
#
# Point plots serve same as bar plots but in a different style. Rather than the full bar, the value of the estimate is represented by the point at a certain height on the other axis. The Point plot show point estimates and confidence intervals using scatter plot glyphs.

# %%
sns.pointplot(data=penguins,x='sex',y='body_mass_g',hue='species')
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %% [markdown]
# **Inference:**
# 1. **Body mass varies across species and sex.** The boxes and whiskers for each combination of species and sex overlap, but there are clear differences in the central tendencies and spreads of the distributions.
# 2. **Male penguins generally have higher body mass than female penguins.** The median lines for male penguins are higher than those for female penguins across all species.
# 3. **The difference in body mass between males and females is more pronounced in Adelie penguins.** The boxes for Adelie penguins are further apart compared to the other species, indicating a larger difference in body mass between male and female Adelies.
#
#
# No matter which species, males eat the most.

# %% [markdown]
# # Facet Grid
#
# Seaborn Facetgrid() function enable us to draw multi-plot grid for plotting conditional relationships.

# %%
g = sns.FacetGrid(data = diamonds,col = 'cut',row='color')
g = g.map(plt.hist, "price")
plt.show()

# %% [markdown]
# **Inference:**
# 1. **The distribution of prices varies across different combinations of color and cut.** The histograms show distinct patterns for different combinations, indicating that both color and cut influence the price distribution.
# 2. **Diamonds with higher clarity grades (Ideal, Premium) tend to have higher prices.** The histograms for these categories generally show a shift towards higher price ranges compared to lower clarity grades.
# 3. **The color of the diamond also affects price.** Certain colors, such as D and H, may have different price distributions compared to other colors.

# %% [markdown]
# # Boxenplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(
    diamonds, x="clarity", y="carat",color="b", order=clarity_ranking, width_method="linear",
)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %% [markdown]
# **Inference:**
# 1. **Carat weight varies across clarity grades.** The boxes and whiskers for different clarity grades overlap, but there are clear differences in the central tendencies and spreads of the distributions.
# 2. **Diamonds with lower clarity grades (I1, SI2) tend to have higher carat weights.** The median lines for these grades are generally higher than those for higher clarity grades.
# 3. **There is more variability in carat weight for lower clarity grades.** The boxes and whiskers for I1 and SI2 are wider, indicating a larger spread of carat weights within these grades.

# %% [markdown]
# # JointGrid

# %%
sns.set_theme(style="ticks")

planets = sns.load_dataset("planets")
g = sns.JointGrid(data=planets, x="year", y="distance", marginal_ticks=True)

g.ax_joint.set(yscale="log")

cax = g.figure.add_axes([.15, .55, .02, .2])

g.plot_joint(
    sns.histplot, discrete=(True, False),
    cmap="light:#03012d", pmax=.8, cbar=True, cbar_ax=cax
)
g.plot_marginals(sns.histplot, element="step", color="#03012d")

# %% [markdown]
# **Inference:**
# 1. **There is a general trend of increasing distance over time.** The scatter plot shows an upward slope, indicating that the distance between the two points tends to increase as the year progresses.
# 2. **The relationship between distance and year is not perfectly linear.** There is some scatter around the trend line, suggesting that other factors besides year may influence the distance.
# 3. **The distribution of distances becomes wider over time.** The histograms on the sides of the plot show that the spread of distances increases as the year progresses, indicating more variability in the distances measured in later years.
